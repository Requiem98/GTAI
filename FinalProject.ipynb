# %%
# %cd /content/drive/MyDrive/AML-Homeworks/Final_Project
# Out:
# /content/drive/.shortcut-targets-by-id/157klPykE3fxPXiVw0zr9qFs8qvCf0c66/AML-Homeworks/Final_Project

# %%
# !mkdir -p dataset/camera dataset/log

# !wget --continue https://archive.org/download/comma-dataset/comma-dataset.zip
# !mkdir -p dataset
# Out:
# --2022-11-25 17:04:08--  https://archive.org/download/comma-dataset/comma-dataset.zip
# Resolving archive.org (archive.org)... 207.241.224.2
# Connecting to archive.org (archive.org)|207.241.224.2|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ia801203.us.archive.org/29/items/comma-dataset/comma-dataset.zip [following]
# --2022-11-25 17:04:09--  https://ia801203.us.archive.org/29/items/comma-dataset/comma-dataset.zip
# Resolving ia801203.us.archive.org (ia801203.us.archive.org)... 207.241.228.23
# Connecting to ia801203.us.archive.org (ia801203.us.archive.org)|207.241.228.23|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 48275578342 (45G) [application/zip]
# Saving to: ‘comma-dataset.zip’
#
# comma-dataset.zip   100%[===================>]  44.96G  2.68MB/s    in 4h 56m
#
# 2022-11-25 22:00:57 (2.59 MB/s) - ‘comma-dataset.zip’ saved [48275578342/48275578342]
#
# ...

# %%
# %cd dataset
# !unzip ../comma-dataset.zip
# Out:
# /content/drive/.shortcut-targets-by-id/157klPykE3fxPXiVw0zr9qFs8qvCf0c66/AML-Homeworks/Final_Project/dataset
# Archive:  ../comma-dataset.zip
#   inflating: LICENSE
#   inflating: camera/2016-01-30--11-24-51.h5
#   inflating: camera/2016-01-30--13-46-00.h5
#   inflating: camera/2016-01-31--19-19-25.h5
#   inflating: camera/2016-02-02--10-16-58.h5
#   inflating: camera/2016-02-08--14-56-28.h5
#   inflating: camera/2016-02-11--21-32-47.h5
#   inflating: camera/2016-03-29--10-50-20.h5
#   inflating: camera/2016-04-21--14-48-08.h5
#   inflating: camera/2016-05-12--22-20-00.h5
#   inflating: camera/2016-06-02--21-39-29.h5
#   inflating: camera/2016-06-08--11-46-01.h5
#   inflating: log/2016-01-30--11-24-51.h5
#   inflating: log/2016-01-30--13-46-00.h5
#   inflating: log/2016-01-31--19-19-25.h5
#   inflating: log/2016-02-02--10-16-58.h5
#   inflating: log/2016-02-08--14-56-28.h5
#   inflating: log/2016-02-11--21-32-47.h5
#   inflating: log/2016-03-29--10-50-20.h5
# ...
