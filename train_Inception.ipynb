# %% [markdown]
# ## Libraries

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# %cd /content/drive/MyDrive/GTAI
# Out:
# Mounted at /content/drive
# /content/drive/Othercomputers/Il mio computer/GTAI

# %%
# !pip install timm
from libraries import *
import baseFunctions as bf
from models import inception_resnet_v2_regr as Inception

plt.style.use('ggplot')
#%cp -r ./Data /content/
# %cd /content/

# %%
train_dataset = bf.GTADataset("data.csv", DATA_ROOT_DIR, bf.preprocess, load_all=False)
dataloader = DataLoader(train_dataset, batch_size=16, shuffle=True, num_workers=2)

# %%
# Select GPU device for the training if available
if not torch.cuda.is_available():
    device=torch.device("cpu")
    print("Current device:", device)
else:
    device=torch.device("cuda")
    print("Current device:", device, "- Type:", torch.cuda.get_device_name(0))
    bf.get_memory()
    

CKP_DIR = "./Data/models/Inception/checkpoint/"
SCORE_DIR = "./Data/models/Inception/scores/"
SCORE_FILE = 'history_score.pkl'



inception = Inception(device=device).to(device)

inception.train_model(dataloader,
                max_epoch=1, 
                log_step=1, 
                ckp_save_step=5, 
                ckp_dir = CKP_DIR, 
                score_dir = SCORE_DIR, 
                score_file = SCORE_FILE)
